# %% [markdown]
# # ACS DATA

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp
from shapely.geometry import Point
import pandas as pd

# %% [markdown]
# # TOTAL POPULATION

# %%
POP_ACS=pd.read_csv('BlockGroup/ACS_15_5YR_B01003_with_ann.csv')
POP_ACS.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label        HD01_VD01  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...             1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...             1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...             1277
#
#                 HD02_VD01
# 0  Margin of Error; Total
# 1                     277
# 2                     315
# 3                     295
# 4                     395

# %%
def drop_margins(start_column,df):
    """
    function to drop out the margin of errors from the acs dataset 
    
    start_column = the column number with the first margin of errors
    df = the acs dataframe
    
    """
    
    i = start_column
    columns = df.columns
    while i< len(columns):
        df = df.drop(columns[i],axis = 1)
        i = i + 2
    return df

# %%
POP = drop_margins(4 ,POP_ACS)
POP.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label        HD01_VD01
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...             1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...             1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...             1277

# %%
#POP.drop(POP.index[0])
#POP.head()

# %% [markdown]
# # MEDIAN INCOME PER HOUSEHOLD

# %%
INCOME_ACS=pd.read_csv('BlockGroup/ACS_15_5YR_B19013_with_ann.csv')
INCOME_ACS.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label  \
# 0                                          Geography
# 1  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                            HD01_VD01  \
# 0  Estimate; Median household income in the past ...
# 1                                              87205
# 2                                             121174
# 3                                              80288
# 4                                              91250
#
#                                            HD02_VD01
# 0  Margin of Error; Median household income in th...
# 1                                              19781
# 2                                              17120
# 3                                              37809
# 4                                              48753

# %%
#keep required columns
#INC = INCOME_ACS[['GEO.id', 'GEO.id2', 'GEO.display-label', 'HC01_EST_VC02','HC02_EST_VC02']]
#INC.head()

# %%
#Drop Margin of Error
INC = drop_margins(4 ,INCOME_ACS)
INC.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label  \
# 0                                          Geography
# 1  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                            HD01_VD01
# 0  Estimate; Median household income in the past ...
# 1                                              87205
# 2                                             121174
# 3                                              80288
# 4                                              91250

# %% [markdown]
# # HOUSEHOLD UNITS

# %%
HH_ACS=pd.read_csv('BlockGroup/ACS_15_5YR_B25001_with_ann.csv')
HH_ACS.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label        HD01_VD01  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              470
# 2  Block Group 2, Census Tract 121.01, Boulder Co...              619
# 3  Block Group 3, Census Tract 121.01, Boulder Co...              554
# 4  Block Group 4, Census Tract 121.01, Boulder Co...              480
#
#                 HD02_VD01
# 0  Margin of Error; Total
# 1                      94
# 2                      99
# 3                      91
# 4                     108

# %%
#Drop Margin of Error
HH = drop_margins(4 ,HH_ACS)
HH.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label        HD01_VD01
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              470
# 2  Block Group 2, Census Tract 121.01, Boulder Co...              619
# 3  Block Group 3, Census Tract 121.01, Boulder Co...              554
# 4  Block Group 4, Census Tract 121.01, Boulder Co...              480

# %% [markdown]
# # EDUCATION(25yrs and over)

# %%
EDU_ACS=pd.read_csv('BlockGroup/ACS_15_5YR_B15003_with_ann.csv')
EDU_ACS.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label         HD01_VD01  \
# 0                                          Geography  Estimate; Total:
# 1  Block Group 1, Census Tract 121.01, Boulder Co...               553
# 2  Block Group 2, Census Tract 121.01, Boulder Co...              1114
# 3  Block Group 3, Census Tract 121.01, Boulder Co...               821
# 4  Block Group 4, Census Tract 121.01, Boulder Co...               835
#
#                  HD02_VD01                                  HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - No schooling completed
# 1                      150                                          0
# 2                      180                                          0
# 3                      200                                          0
# 4                      203                                          0
#
#                                           HD02_VD02  \
# 0  Margin of Error; Total: - No schooling completed
# 1                                                11
# 2                                                11
# 3                                                11
# 4                                                11
#
#                            HD01_VD03  \
# 0  Estimate; Total: - Nursery school
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
#
#                                   HD02_VD03                        HD01_VD04  \
# 0  Margin of Error; Total: - Nursery school  Estimate; Total: - Kindergarten
# 1                                        11                                0
# 2                                        11                                0
# 3                                        11                                0
# 4                                        11                                0
#
#                       ...                      \
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
#
#                                HD01_VD21  \
# 0  Estimate; Total: - Associate's degree
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                     20
#
#                                       HD02_VD21  \
# 0  Margin of Error; Total: - Associate's degree
# 1                                            11
# 2                                            11
# 3                                            11
# 4                                            33
#
#                               HD01_VD22  \
# 0  Estimate; Total: - Bachelor's degree
# 1                                   209
# 2                                   376
# 3                                   195
# 4                                   242
#
#                                      HD02_VD22  \
# 0  Margin of Error; Total: - Bachelor's degree
# 1                                          105
# 2                                          103
# 3                                           82
# 4                                          184
#
#                             HD01_VD23  \
# 0  Estimate; Total: - Master's degree
# 1                                 160
# 2                                 372
# 3                                 342
# 4                                 289
#
#                                    HD02_VD23  \
# 0  Margin of Error; Total: - Master's degree
# 1                                         89
# 2                                        158
# 3                                        121
# 4                                         97
#
#                                        HD01_VD24  \
# 0  Estimate; Total: - Professional school degree
# 1                                             90
# 2                                            108
# 3                                             14
# 4                                             19
#
#                                            HD02_VD24  \
# 0  Margin of Error; Total: - Professional school ...
# 1                                                 60
# 2                                                 72
# 3                                                 23
# 4                                                 26
#
#                              HD01_VD25  \
# 0  Estimate; Total: - Doctorate degree
# 1                                   22
# 2                                   66
# 3                                  152
# 4                                   36
#
#                                     HD02_VD25
# 0  Margin of Error; Total: - Doctorate degree
# 1                                          25
# 2                                          75
# 3                                          81
# 4                                          33
#
# [5 rows x 53 columns]

# %%
#keep required columns
EDU = EDU_ACS[['GEO.id', 'GEO.id2', 'GEO.display-label', 'HD01_VD22', 'HD01_VD23']]
EDU.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label  \
# 0                                          Geography
# 1  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                               HD01_VD22                           HD01_VD23
# 0  Estimate; Total: - Bachelor's degree  Estimate; Total: - Master's degree
# 1                                   209                                 160
# 2                                   376                                 372
# 3                                   195                                 342
# 4                                   242                                 289

# %% [markdown]
# # ALTERNATIVE COMMUTERS

# %%
#Alternative Commuters
AltCom_ACS=pd.read_csv('BlockGroup/ACS_15_5YR_B08301_with_ann.csv')
AltCom_ACS.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label         HD01_VD01  \
# 0                                          Geography  Estimate; Total:
# 1  Block Group 1, Census Tract 121.01, Boulder Co...               540
# 2  Block Group 2, Census Tract 121.01, Boulder Co...               674
# 3  Block Group 3, Census Tract 121.01, Boulder Co...               638
# 4  Block Group 4, Census Tract 121.01, Boulder Co...               793
#
#                  HD02_VD01                      HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Car, truck, or van:
# 1                      197                            378
# 2                      172                            413
# 3                      184                            332
# 4                      369                            485
#
#                               HD02_VD02  \
# 0  Margin of Error; Car, truck, or van:
# 1                                   192
# 2                                   172
# 3                                   119
# 4                                   289
#
#                                      HD01_VD03  \
# 0  Estimate; Car, truck, or van: - Drove alone
# 1                                          263
# 2                                          382
# 3                                          298
# 4                                          434
#
#                                            HD02_VD03  \
# 0  Margin of Error; Car, truck, or van: - Drove a...
# 1                                                125
# 2                                                169
# 3                                                106
# 4                                                283
#
#                                     HD01_VD04  \
# 0  Estimate; Car, truck, or van: - Carpooled:
# 1                                         115
# 2                                          31
# 3                                          34
# 4                                          51
#
#                 ...                            HD01_VD17  \
# 0               ...                 Estimate; Motorcycle
# 1               ...                                    0
# 2               ...                                    0
# 3               ...                                    0
# 4               ...                                    0
#
#                      HD02_VD17          HD01_VD18                 HD02_VD18  \
# 0  Margin of Error; Motorcycle  Estimate; Bicycle  Margin of Error; Bicycle
# 1                           11                 76                        66
# 2                           11                 68                        51
# 3                           11                 62                        59
# 4                           11                 54                        39
#
#           HD01_VD19                HD02_VD19              HD01_VD20  \
# 0  Estimate; Walked  Margin of Error; Walked  Estimate; Other means
# 1                34                       52                      0
# 2                15                       23                      0
# 3                31                       35                      0
# 4                63                       55                      0
#
#                       HD02_VD20                 HD01_VD21  \
# 0  Margin of Error; Other means  Estimate; Worked at home
# 1                            11                        38
# 2                            11                       161
# 3                            11                       113
# 4                            11                       120
#
#                          HD02_VD21
# 0  Margin of Error; Worked at home
# 1                               38
# 2                               90
# 3                               72
# 4                              101
#
# [5 rows x 45 columns]

# %%
#keep required columns
AC = AltCom_ACS[['GEO.id', 'GEO.id2', 'GEO.display-label', 'HD01_VD10','HD01_VD16', 'HD01_VD17', 'HD01_VD18', 'HD01_VD19']]
AC.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                    GEO.display-label  \
# 0                                          Geography
# 1  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                            HD01_VD10          HD01_VD16  \
# 0  Estimate; Public transportation (excluding tax...  Estimate; Taxicab
# 1                                                 14                  0
# 2                                                 17                  0
# 3                                                100                  0
# 4                                                 71                  0
#
#               HD01_VD17          HD01_VD18         HD01_VD19
# 0  Estimate; Motorcycle  Estimate; Bicycle  Estimate; Walked
# 1                     0                 76                34
# 2                     0                 68                15
# 3                     0                 62                31
# 4                     0                 54                63

# %%
#AC=AC.drop(AC.index[0]).head()
#AC

# %%
#add all columns - ERROR
#AC['AltCommuters'] = AC.apply(lambda row: row['HD01_VD10'] + row['HD01_VD16']+ row['HD01_VD17']+ row['HD01_VD18']+ row['HD01_VD19'], axis=1)
#AC

# %%
#AC['AC'] = AC['HD01_VD10'] - AC['HD01_VD16'] - AC['HD01_VD17'] - AC['HD01_VD19']
#AC

# %%
AC.to_csv('BlockGroup/AC.csv')

# %%
AC_total=pd.read_csv('BlockGroup/AC_Estimate.csv')
AC_total.head()
# Out:
#                   GEO.id      GEO.id2  \
# 0                     Id          Id2
# 1  1500000US080130121011  80130121011
# 2  1500000US080130121012  80130121012
# 3  1500000US080130121013  80130121013
# 4  1500000US080130121014  80130121014
#
#                                    GEO.display-label  \
# 0                                          Geography
# 1  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                            HD01_VD10          HD01_VD16  \
# 0  Estimate; Public transportation (excluding tax...  Estimate; Taxicab
# 1                                                 14                  0
# 2                                                 17                  0
# 3                                                100                  0
# 4                                                 71                  0
#
#               HD01_VD17          HD01_VD18         HD01_VD19  \
# 0  Estimate; Motorcycle  Estimate; Bicycle  Estimate; Walked
# 1                     0                 76                34
# 2                     0                 68                15
# 3                     0                 62                31
# 4                     0                 54                63
#
#   Alternate Commuters
# 0             AltComm
# 1                 124
# 2                 100
# 3                 193
# 4                 188

# %%
#keep required columns
AltCommuters= AC_total[['GEO.id', 'GEO.id2', 'GEO.display-label', 'Alternate Commuters']]
AltCommuters.head()
# Out:
#                   GEO.id      GEO.id2  \
# 0                     Id          Id2
# 1  1500000US080130121011  80130121011
# 2  1500000US080130121012  80130121012
# 3  1500000US080130121013  80130121013
# 4  1500000US080130121014  80130121014
#
#                                    GEO.display-label Alternate Commuters
# 0                                          Geography             AltComm
# 1  Block Group 1, Census Tract 121.01, Boulder Co...                 124
# 2  Block Group 2, Census Tract 121.01, Boulder Co...                 100
# 3  Block Group 3, Census Tract 121.01, Boulder Co...                 193
# 4  Block Group 4, Census Tract 121.01, Boulder Co...                 188

# %% [markdown]
# # GROUPING DATA

# %%
#GROUP POP and INC
Data = pd.merge(POP, INC, how = 'left', left_on = "GEO.id", right_on = "GEO.id")
Data.head()
# Out:
#                   GEO.id     GEO.id2_x  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                  GEO.display-label_x      HD01_VD01_x  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...             1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...             1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...             1277
#
#       GEO.id2_y                                GEO.display-label_y  \
# 0           Id2                                          Geography
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                          HD01_VD01_y
# 0  Estimate; Median household income in the past ...
# 1                                              87205
# 2                                             121174
# 3                                              80288
# 4                                              91250

# %%
#Add HH
Data = pd.merge(Data, HH, how ='left', left_on = "GEO.id", right_on = "GEO.id")
Data.head()
# Out:
#                   GEO.id     GEO.id2_x  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                  GEO.display-label_x      HD01_VD01_x  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...             1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...             1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...             1277
#
#       GEO.id2_y                                GEO.display-label_y  \
# 0           Id2                                          Geography
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                          HD01_VD01_y       GEO.id2  \
# 0  Estimate; Median household income in the past ...           Id2
# 1                                              87205  080130121011
# 2                                             121174  080130121012
# 3                                              80288  080130121013
# 4                                              91250  080130121014
#
#                                    GEO.display-label        HD01_VD01
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              470
# 2  Block Group 2, Census Tract 121.01, Boulder Co...              619
# 3  Block Group 3, Census Tract 121.01, Boulder Co...              554
# 4  Block Group 4, Census Tract 121.01, Boulder Co...              480

# %%
#merge EDU
Data = pd.merge(Data, EDU, left_on = "GEO.id", right_on = "GEO.id")
Data.head()
# Out:
#                   GEO.id     GEO.id2_x  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                  GEO.display-label_x      HD01_VD01_x  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...             1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...             1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...             1277
#
#       GEO.id2_y                                GEO.display-label_y  \
# 0           Id2                                          Geography
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                          HD01_VD01_y     GEO.id2_x  \
# 0  Estimate; Median household income in the past ...           Id2
# 1                                              87205  080130121011
# 2                                             121174  080130121012
# 3                                              80288  080130121013
# 4                                              91250  080130121014
#
#                                  GEO.display-label_x        HD01_VD01  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              470
# 2  Block Group 2, Census Tract 121.01, Boulder Co...              619
# 3  Block Group 3, Census Tract 121.01, Boulder Co...              554
# 4  Block Group 4, Census Tract 121.01, Boulder Co...              480
#
#       GEO.id2_y                                GEO.display-label_y  \
# 0           Id2                                          Geography
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                               HD01_VD22                           HD01_VD23
# 0  Estimate; Total: - Bachelor's degree  Estimate; Total: - Master's degree
# 1                                   209                                 160
# 2                                   376                                 372
# 3                                   195                                 342
# 4                                   242                                 289

# %%
#merge Alt Commuters
Data = pd.merge(Data, AltCommuters, left_on = "GEO.id", right_on = "GEO.id")
Data.head()
# Out:
#                   GEO.id     GEO.id2_x  \
# 0                     Id           Id2
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
#
#                                  GEO.display-label_x      HD01_VD01_x  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...             1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...             1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...             1277
#
#       GEO.id2_y                                GEO.display-label_y  \
# 0           Id2                                          Geography
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                                          HD01_VD01_y     GEO.id2_x  \
# 0  Estimate; Median household income in the past ...           Id2
# 1                                              87205  080130121011
# 2                                             121174  080130121012
# 3                                              80288  080130121013
# 4                                              91250  080130121014
#
#                                  GEO.display-label_x        HD01_VD01  \
# 0                                          Geography  Estimate; Total
# 1  Block Group 1, Census Tract 121.01, Boulder Co...              470
# 2  Block Group 2, Census Tract 121.01, Boulder Co...              619
# 3  Block Group 3, Census Tract 121.01, Boulder Co...              554
# 4  Block Group 4, Census Tract 121.01, Boulder Co...              480
#
#       GEO.id2_y                                GEO.display-label_y  \
# 0           Id2                                          Geography
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#                               HD01_VD22                           HD01_VD23  \
# 0  Estimate; Total: - Bachelor's degree  Estimate; Total: - Master's degree
# 1                                   209                                 160
# 2                                   376                                 372
# 3                                   195                                 342
# 4                                   242                                 289
#
#        GEO.id2                                  GEO.display-label  \
# 0          Id2                                          Geography
# 1  80130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  80130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  80130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  80130121014  Block Group 4, Census Tract 121.01, Boulder Co...
#
#   Alternate Commuters
# 0             AltComm
# 1                 124
# 2                 100
# 3                 193
# 4                 188

# %%
#Drop first row
Data2=Data.drop(Data.index[0])
Data2.head()
# Out:
#                   GEO.id     GEO.id2_x  \
# 1  1500000US080130121011  080130121011
# 2  1500000US080130121012  080130121012
# 3  1500000US080130121013  080130121013
# 4  1500000US080130121014  080130121014
# 5  1500000US080130121021  080130121021
#
#                                  GEO.display-label_x HD01_VD01_x  \
# 1  Block Group 1, Census Tract 121.01, Boulder Co...         856
# 2  Block Group 2, Census Tract 121.01, Boulder Co...        1518
# 3  Block Group 3, Census Tract 121.01, Boulder Co...        1202
# 4  Block Group 4, Census Tract 121.01, Boulder Co...        1277
# 5  Block Group 1, Census Tract 121.02, Boulder Co...        1715
#
#       GEO.id2_y                                GEO.display-label_y  \
# 1  080130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  080130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  080130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  080130121014  Block Group 4, Census Tract 121.01, Boulder Co...
# 5  080130121021  Block Group 1, Census Tract 121.02, Boulder Co...
#
#   HD01_VD01_y     GEO.id2_x  \
# 1       87205  080130121011
# 2      121174  080130121012
# 3       80288  080130121013
# 4       91250  080130121014
# 5       43929  080130121021
#
#                                  GEO.display-label_x HD01_VD01     GEO.id2_y  \
# 1  Block Group 1, Census Tract 121.01, Boulder Co...       470  080130121011
# 2  Block Group 2, Census Tract 121.01, Boulder Co...       619  080130121012
# 3  Block Group 3, Census Tract 121.01, Boulder Co...       554  080130121013
# 4  Block Group 4, Census Tract 121.01, Boulder Co...       480  080130121014
# 5  Block Group 1, Census Tract 121.02, Boulder Co...       868  080130121021
#
#                                  GEO.display-label_y HD01_VD22 HD01_VD23  \
# 1  Block Group 1, Census Tract 121.01, Boulder Co...       209       160
# 2  Block Group 2, Census Tract 121.01, Boulder Co...       376       372
# 3  Block Group 3, Census Tract 121.01, Boulder Co...       195       342
# 4  Block Group 4, Census Tract 121.01, Boulder Co...       242       289
# 5  Block Group 1, Census Tract 121.02, Boulder Co...       456       265
#
#        GEO.id2                                  GEO.display-label  \
# 1  80130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2  80130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3  80130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4  80130121014  Block Group 4, Census Tract 121.01, Boulder Co...
# 5  80130121021  Block Group 1, Census Tract 121.02, Boulder Co...
#
#   Alternate Commuters
# 1                 124
# 2                 100
# 3                 193
# 4                 188
# 5                 471

# %%
Data2.columns
# Out:
# Index(['GEO.id', 'GEO.id2_x', 'GEO.display-label_x', 'HD01_VD01_x',
#        'GEO.id2_y', 'GEO.display-label_y', 'HD01_VD01_y', 'GEO.id2_x',
#        'GEO.display-label_x', 'HD01_VD01', 'GEO.id2_y', 'GEO.display-label_y',
#        'HD01_VD22', 'HD01_VD23', 'GEO.id2', 'GEO.display-label',
#        'Alternate Commuters'],
#       dtype='object')

# %%
Data2.drop(['GEO.id2_y', 'GEO.display-label_y','GEO.id2_x',
       'GEO.display-label_x' ], axis=1, inplace=True)

# %%
Data2.head()
# Out:
#                   GEO.id HD01_VD01_x HD01_VD01_y HD01_VD01 HD01_VD22  \
# 1  1500000US080130121011         856       87205       470       209
# 2  1500000US080130121012        1518      121174       619       376
# 3  1500000US080130121013        1202       80288       554       195
# 4  1500000US080130121014        1277       91250       480       242
# 5  1500000US080130121021        1715       43929       868       456
#
#   HD01_VD23      GEO.id2                                  GEO.display-label  \
# 1       160  80130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2       372  80130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3       342  80130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4       289  80130121014  Block Group 4, Census Tract 121.01, Boulder Co...
# 5       265  80130121021  Block Group 1, Census Tract 121.02, Boulder Co...
#
#   Alternate Commuters
# 1                 124
# 2                 100
# 3                 193
# 4                 188
# 5                 471

# %% [markdown]
# Data2['GEO.id'] = Final['Geo.id']
# Data2['GEO.id2'] = Final['Geo.id2']
# Data2['GEO.display-label'] = Final['Geo.display-label']
# Data2['POP'] = Final['HD01_VD01_x']
# Data2['INC'] = Final['HD01_VD01_y']
# Data2['HH'] = Final['HD01_VD01']
# Data2['Bachelors'] = Final['HD01_VD22']
# Data2['Graduate'] = Final['HD01_VD23']

# %%
Data2.head()
# Out:
#                   GEO.id HD01_VD01_x HD01_VD01_y HD01_VD01 HD01_VD22  \
# 1  1500000US080130121011         856       87205       470       209
# 2  1500000US080130121012        1518      121174       619       376
# 3  1500000US080130121013        1202       80288       554       195
# 4  1500000US080130121014        1277       91250       480       242
# 5  1500000US080130121021        1715       43929       868       456
#
#   HD01_VD23      GEO.id2                                  GEO.display-label  \
# 1       160  80130121011  Block Group 1, Census Tract 121.01, Boulder Co...
# 2       372  80130121012  Block Group 2, Census Tract 121.01, Boulder Co...
# 3       342  80130121013  Block Group 3, Census Tract 121.01, Boulder Co...
# 4       289  80130121014  Block Group 4, Census Tract 121.01, Boulder Co...
# 5       265  80130121021  Block Group 1, Census Tract 121.02, Boulder Co...
#
#   Alternate Commuters
# 1                 124
# 2                 100
# 3                 193
# 4                 188
# 5                 471

# %%
Data2.to_csv('BlockGroup/ACS_Combined.csv')
